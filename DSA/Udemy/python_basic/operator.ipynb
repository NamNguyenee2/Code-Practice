# %% [markdown]
# ## Arithmetic Operators
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Floor Division
# - Modulus
# - Exponentiation

# %% [markdown]
# ## Comparison Operators
# - Equal to
# - Not equal to
# - Greater than
# - Less than
# - Greater than or equal to
# - Less than or equal to

# %% [markdown]
# ## Logical Operators
# - AND
# - OR
# - NOT
